# %%
print("hello!!..")
# Out:
# hello!!..

# %%
import logging
import os
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 8, 23, 18, 41, 16, 984000)

# %%
f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
# Out:
# '08_23_2024_18_41_16.log'

# %%
os.path.join(os.getcwd(),"logs")
# Out:
# '/Users/vipulmore/Documents/vscode/end_to_end_project/notebooks/logs'

# %%
from src.DimondPricePrediction.logger import logging

# %%
logging.info("i have just tested the things")

# %%
import sys

# %%
try:
    a=1/0
except Exception as e:
    print(sys.exc_info())
    print(e)
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x10573d140>)
# division by zero

# %%
import sys


class customexception(Exception):
    def __init__(self,error_message,error_details:sys):
        self.error_message=error_message
        _,_,exe_tb=error_details.exc_info()
        
        self.lineno=exe_tb.tb_lineno
        self.file_name=exe_tb.tb_frame.f_code.co_filename

    def __str__(self):
        return "Error accour in python script name[{0}] line number [{1}] error message[{2}]". format(
        self.file_name, self.lineno, str(self.error_message))




if __name__=="__main__":
    try:

        a=1/0

    except Exception as e:
        raise customexception(e,sys)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 22
#      20 try:
# ---> 22     a=1/0
#      24 except Exception as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# customexception                           Traceback (most recent call last)
# Cell In[11], line 25
#      22     a=1/0
#      24 except Exception as e:
# ---> 25     raise customexception(e,sys)
#
# customexception: Error accour in python script name[/var/folders/35/0j8ydkls3cz51kzd15706tmc0000gn/T/ipykernel_5542/2152118648.py] line number [22] error message[division by zero]

# %%
try:
    a=1/0
except Exception as e:
    _,_,exc_tb=sys.exc_info()
    print(exc_tb.tb_lineno)
    print(exc_tb.tb_frame.f_code.co_filename)

    print(e)
# Out:
# 2
# /var/folders/35/0j8ydkls3cz51kzd15706tmc0000gn/T/ipykernel_5542/713169860.py
# division by zero

# %%
class customexception(Exception):
    def __init__(self):
        pass

    def str(self):
        pass

# %%
raise customexception(e,sys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 raise customexception(e,sys)
#
# NameError: name 'e' is not defined

# %%
sys.exc_info()
# Out:
# (None, None, None)

# %%
import os
os.makedirs(os.path.dirname(os.path.join("artifacts","raw.csv")),exist_ok=True)
